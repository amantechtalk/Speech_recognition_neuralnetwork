# %%
from keras.layers import LSTM, Dense, Dropout, Embedding, Masking, Bidirectional,Flatten, SpatialDropout1D,SpatialDropout2D,SpatialDropout3D
from python_speech_features import mfcc
from python_speech_features import logfbank
from keras.models import Sequential, load_model
from keras.optimizers import adam_v2
from keras.utils import np_utils
from keras.utils.vis_utils import plot_model
from keras.preprocessing.text import Tokenizer
from keras_preprocessing.sequence import pad_sequences
from sklearn.preprocessing import LabelEncoder,normalize
from matplotlib import pyplot
from keras.callbacks import EarlyStopping
from sklearn.preprocessing import MinMaxScaler
import scipy.io.wavfile as wav
import numpy as np
import keras
import csv
import os
import time

#Calculating x_test and y_test
scaler = MinMaxScaler(feature_range=(0,1))
test_labels = []
test_data = []

#test_labels.txt is a txt file with all labels for the speech samples that is required for the evaluation. We loop through it to calculate the MFCC value for each speech sample and then normalize it 
with open('C:/Users/amank/Downloads/audiodetect/bed/test.csv', newline='') as tsvfile:
    reader = csv.DictReader(tsvfile)
    
    reader = csv.reader(tsvfile, delimiter=',')
    
    for row in reader:
        
        wav_file = "C:/Users/amank/Downloads/audiodetect/bed/" + row[0]
        (rate,sig) = wav.read(wav_file)
       
        #Getting the MFCC value from the .wav files.
        if(int(sig.shape[0])>=70000):
            mfcc_feat = mfcc(sig[45000:55000],rate)      
        elif(int(sig.shape[0])>=60000):
            mfcc_feat = mfcc(sig[45000:55000],rate)
        elif(int(sig.shape[0])>=50000):
            mfcc_feat = mfcc(sig[30000:40000],rate)            
  
        elif(int(sig.shape[0])>=40000):
            mfcc_feat = mfcc(sig[25000:35000],rate)


        elif(int(sig.shape[0])>=30000):
            mfcc_feat = mfcc(sig[10000:20000],rate)
        elif(int(sig.shape[0])>=20000):
            mfcc_feat = mfcc(sig[5000:15000],rate)            
  
        elif(int(sig.shape[0])>=10000):
            mfcc_feat = mfcc(sig[1000:11000],rate)
        else:
            mfcc_feat = mfcc(sig[1000:11000],rate)
         
        scaler = scaler.fit(mfcc_feat)

        #Normalizing the MFCC values.
        normalized = scaler.transform(mfcc_feat)
        normalized=np.hstack((normalized,normalized))
        normalized=np.hstack((normalized,normalized))
        if(normalized.shape[0]==61) : 
         test_data.append(normalized)
         test_labels.append(str(row[1]))
        










with open('C:/Users/amank/Downloads/audiodetect/cat/test.csv', newline='') as tsvfile:
    reader = csv.DictReader(tsvfile)
    reader = csv.reader(tsvfile, delimiter=',')
    for row in reader:
        wav_file = "C:/Users/amank/Downloads/audiodetect/cat/" + row[0]
        (rate,sig) = wav.read(wav_file)
       
        #Getting the MFCC value from the .wav files.
        if(int(sig.shape[0])>=70000):
            mfcc_feat = mfcc(sig[45000:55000],rate)      
        elif(int(sig.shape[0])>=60000):
            mfcc_feat = mfcc(sig[45000:55000],rate)
        elif(int(sig.shape[0])>=50000):
            mfcc_feat = mfcc(sig[30000:40000],rate)            
  
        elif(int(sig.shape[0])>=40000):
            mfcc_feat = mfcc(sig[25000:35000],rate)


        elif(int(sig.shape[0])>=30000):
            mfcc_feat = mfcc(sig[10000:20000],rate)
        elif(int(sig.shape[0])>=20000):
            mfcc_feat = mfcc(sig[5000:15000],rate)            
  
        elif(int(sig.shape[0])>=10000):
            mfcc_feat = mfcc(sig[1000:11000],rate)
        else:
            mfcc_feat = mfcc(sig[1000:11000],rate)
         
        scaler = scaler.fit(mfcc_feat)

        #Normalizing the MFCC values.
        normalized = scaler.transform(mfcc_feat)
        normalized=np.hstack((normalized,normalized))
        normalized=np.hstack((normalized,normalized))
        if(normalized.shape[0]==61) : 
         test_data.append(normalized)
         test_labels.append(str(row[1]))
        








with open('C:/Users/amank/Downloads/audiodetect/happy/test.csv', newline='') as tsvfile:
    reader = csv.DictReader(tsvfile)
    reader = csv.reader(tsvfile, delimiter=',')
    for row in reader:
        wav_file = "C:/Users/amank/Downloads/audiodetect/happy/" + row[0]
        (rate,sig) = wav.read(wav_file)
       
        #Getting the MFCC value from the .wav files.
        if(int(sig.shape[0])>=70000):
            mfcc_feat = mfcc(sig[45000:55000],rate)      
        elif(int(sig.shape[0])>=60000):
            mfcc_feat = mfcc(sig[45000:55000],rate)
        elif(int(sig.shape[0])>=50000):
            mfcc_feat = mfcc(sig[30000:40000],rate)            
  
        elif(int(sig.shape[0])>=40000):
            mfcc_feat = mfcc(sig[25000:35000],rate)


        elif(int(sig.shape[0])>=30000):
            mfcc_feat = mfcc(sig[10000:20000],rate)
        elif(int(sig.shape[0])>=20000):
            mfcc_feat = mfcc(sig[5000:15000],rate)            
  
        elif(int(sig.shape[0])>=10000):
            mfcc_feat = mfcc(sig[1000:11000],rate)
        else:
            mfcc_feat = mfcc(sig[1000:11000],rate)
         
        scaler = scaler.fit(mfcc_feat)

        #Normalizing the MFCC values.
        normalized = scaler.transform(mfcc_feat)
        normalized=np.hstack((normalized,normalized))
        normalized=np.hstack((normalized,normalized))
        if(normalized.shape[0]==61) : 
         test_data.append(normalized)
         test_labels.append(str(row[1]))
        
    label_encoder_test = LabelEncoder()
    vec_test = label_encoder_test.fit_transform(test_labels)
   
    #One hot encoding the labels
    one_hot_labels_test = keras.utils.to_categorical(vec_test, num_classes=3)
    Y_test = one_hot_labels_test
    X_test = np.array(test_data,dtype=np.float32)









#Loading x_train
train_labels = []

#train_labels.txt is a txt file with all labels for the speech samples that is required for the evaluation. We loop through it to calculate the MFCC value for each speech sample and then normalize it 
with open('C:/Users/amank/Downloads/audiodetect/bed/train.csv', newline='') as tsvfile:
    reader = csv.DictReader(tsvfile)
    reader = csv.reader(tsvfile, delimiter=',')
    X_train = []
    for row in reader:
        wav_file = "C:/Users/amank/Downloads/audiodetect/bed/" + row[0]
        (rate,sig) = wav.read(wav_file)
        
        #Getting the MFCC value from the .wav files.
       

        if(int(sig.shape[0])>=70000):
            mfcc_feat = mfcc(sig[45000:55000],rate)      
        elif(int(sig.shape[0])>=60000):
            mfcc_feat = mfcc(sig[45000:55000],rate)
        elif(int(sig.shape[0])>=50000):
            mfcc_feat = mfcc(sig[30000:40000],rate)            
  
        elif(int(sig.shape[0])>=40000):
            mfcc_feat = mfcc(sig[25000:35000],rate)


        elif(int(sig.shape[0])>=30000):
            mfcc_feat = mfcc(sig[10000:20000],rate)
        elif(int(sig.shape[0])>=20000):
            mfcc_feat = mfcc(sig[5000:15000],rate)            
  
        elif(int(sig.shape[0])>=10000):
            mfcc_feat = mfcc(sig[1000:11000],rate)
        else:
            mfcc_feat = mfcc(sig[1000:11000],rate)
              
        scaler = scaler.fit(mfcc_feat)
        
        normalized = scaler.transform(mfcc_feat)
        normalized=np.hstack((normalized,normalized))
        normalized=np.hstack((normalized,normalized))
        if(normalized.shape[0]==61) : 
         X_train.append(np.array(normalized, dtype=np.float32))
         train_labels.append(str(row[1]))
with open('C:/Users/amank/Downloads/audiodetect/cat/train.csv', newline='') as tsvfile:
    reader = csv.DictReader(tsvfile)
    reader = csv.reader(tsvfile, delimiter=',')
    
    for row in reader:
        wav_file = "C:/Users/amank/Downloads/audiodetect/cat/" + row[0]
        (rate,sig) = wav.read(wav_file)
        
        #Getting the MFCC value from the .wav files.
       

        if(int(sig.shape[0])>=70000):
            mfcc_feat = mfcc(sig[45000:55000],rate)      
        elif(int(sig.shape[0])>=60000):
            mfcc_feat = mfcc(sig[45000:55000],rate)
        elif(int(sig.shape[0])>=50000):
            mfcc_feat = mfcc(sig[30000:40000],rate)            
  
        elif(int(sig.shape[0])>=40000):
            mfcc_feat = mfcc(sig[25000:35000],rate)


        elif(int(sig.shape[0])>=30000):
            mfcc_feat = mfcc(sig[10000:20000],rate)
        elif(int(sig.shape[0])>=20000):
            mfcc_feat = mfcc(sig[5000:15000],rate)            
  
        elif(int(sig.shape[0])>=10000):
            mfcc_feat = mfcc(sig[1000:11000],rate)
        else:
            mfcc_feat = mfcc(sig[1000:11000],rate)
              
        scaler = scaler.fit(mfcc_feat)
        
        normalized = scaler.transform(mfcc_feat)
        normalized=np.hstack((normalized,normalized))
        normalized=np.hstack((normalized,normalized))
        if(normalized.shape[0]==61) : 
         X_train.append(np.array(normalized, dtype=np.float32))
         train_labels.append(str(row[1]))

with open('C:/Users/amank/Downloads/audiodetect/happy/train.csv', newline='') as tsvfile:
    reader = csv.DictReader(tsvfile)
    reader = csv.reader(tsvfile, delimiter=',')
    
    for row in reader:
        wav_file = "C:/Users/amank/Downloads/audiodetect/happy/" + row[0]
        (rate,sig) = wav.read(wav_file)
        
        #Getting the MFCC value from the .wav files.
       

        if(int(sig.shape[0])>=70000):
            mfcc_feat = mfcc(sig[45000:55000],rate)      
        elif(int(sig.shape[0])>=60000):
            mfcc_feat = mfcc(sig[45000:55000],rate)
        elif(int(sig.shape[0])>=50000):
            mfcc_feat = mfcc(sig[30000:40000],rate)            
  
        elif(int(sig.shape[0])>=40000):
            mfcc_feat = mfcc(sig[25000:35000],rate)


        elif(int(sig.shape[0])>=30000):
            mfcc_feat = mfcc(sig[10000:20000],rate)
        elif(int(sig.shape[0])>=20000):
            mfcc_feat = mfcc(sig[5000:15000],rate)            
  
        elif(int(sig.shape[0])>=10000):
            mfcc_feat = mfcc(sig[1000:11000],rate)
        else:
            mfcc_feat = mfcc(sig[1000:11000],rate)
              
        scaler = scaler.fit(mfcc_feat)
        
        normalized = scaler.transform(mfcc_feat)
        normalized=np.hstack((normalized,normalized))
        normalized=np.hstack((normalized,normalized))
        if(normalized.shape[0]==61) : 
         X_train.append(np.array(normalized, dtype=np.float32))
         train_labels.append(str(row[1]))



         
print(rate,sig,mfcc_feat,normalized)

X_train_array = np.array(X_train)


#calculate y_train
label_encoder = LabelEncoder()
vec = label_encoder.fit_transform(train_labels)
one_hot_labels_train = keras.utils.np_utils.to_categorical(vec, num_classes=3)
Y_train = one_hot_labels_train
print(X_train_array.shape,Y_train.shape, X_test.shape,Y_test.shape)




from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import MaxPooling2D





model_11 = Sequential()
model_11.add(LSTM(200,input_shape=(61,52),return_sequences=False))
model_11.add(Dense(3,activation='softmax'))
model_11.summary()

model_11.compile(optimizer=Adam(amsgrad=True, lr=0.001),loss='categorical_crossentropy',metrics=['accuracy'])
EPOCHS = 100
BATCH_SIZE = 40

#Training the model
history = model_11.fit(X_train_array, 
                    Y_train, 
                    epochs=EPOCHS,
                   # callbacks = callbacks,
                    batch_size=BATCH_SIZE,
                    validation_data=(X_test, Y_test),
                    verbose=1,
                    shuffle=True
                   )


#plotting the loss
history = model_11.history
#print(history.history['loss'])
#print(history.history['val_loss'])
pyplot.plot(history.history['loss'])
pyplot.plot(history.history["val_loss"])
pyplot.title("train and validation loss")
pyplot.ylabel("value")
pyplot.xlabel("epoch")
pyplot.legend(['train','validation'])
pyplot.show()
#plotting the loss
history = model_11.history
#print(history.history['loss'])
#print(history.history['val_loss'])
pyplot.plot(history.history['accuracy'])
pyplot.plot(history.history["val_accuracy"])
pyplot.title("train and validation accuracy")
pyplot.ylabel("accuracy value")
pyplot.xlabel("epoch")
pyplot.legend(['train','validation'])
pyplot.show()
scores = model_11.evaluate(X_test, Y_test, verbose=1)


model_11.save_weights('model.h5')
# Out:
# 16000 [3 4 2 ... 7 3 4] [[ 6.47350386e+00 -1.59117033e+01  4.99556107e+00 -3.79299957e+00
#   -2.41082436e+00 -3.15497175e+00 -5.02002961e-01  1.59151620e+00
#   -1.74459969e+00 -8.31227997e+00 -1.20490553e+01 -6.88674725e+00
#   -2.85631645e+00]
#  [ 6.48255527e+00 -1.79450589e+01 -8.23085692e-01 -7.71218216e+00
#   -7.30646126e+00 -8.61211235e+00 -1.30014954e+00  1.04379394e+00
#   -5.38293366e+00 -9.51232308e+00 -1.22488300e+01 -9.00106781e+00
#   -4.00564683e+00]
#  [ 6.51700704e+00 -1.58605857e+01 -6.10745283e-01 -6.95305991e+00
#   -1.98083325e+00 -5.67051396e+00  3.51788805e+00  9.74364894e-01
#   -9.91154539e+00 -1.17249425e+01 -1.07937456e+01 -6.65292147e+00
#   -2.71284961e+00]
#  [ 6.49859124e+00 -1.68643673e+01 -1.28861598e+00 -7.99677033e+00
#   -4.70745254e+00 -6.03226579e+00  1.13642096e-01 -2.85419505e+00
#   -1.34311575e+01 -1.00811572e+01 -1.07617931e+01 -4.86833298e+00
#    1.28957013e+00]
#  [ 6.42126827e+00 -1.72380507e+01 -1.74230249e+00 -5.19959326e+00
#   -3.47702147e+00 -1.83456027e+00  1.78636706e+00 -7.19875939e+00
#   -1.20822180e+01 -1.04465169e+01 -9.38921299e+00  4.28346198e+00
#    1.02103962e+01]
#  [ 6.43487772e+00 -1.81840728e+01 -9.19040295e-01 -5.74817462e+00
#   -8.80695849e+00 -4.75175807e+00  2.61575486e+00 -2.24848906e+00
#   -9.91412137e+00 -1.19626591e+01 -5.81712197e+00  3.59873353e+00
#    1.31370741e+00]
#  [ 6.42366682e+00 -1.81314818e+01 -1.07124558e+00 -1.01945380e+01
# Epoch 22/100
# 98/98 [==============================] - 15s 156ms/step - loss: 0.0403 - accuracy: 0.9853 - val_loss: 0.1659 - val_accuracy: 0.9477
# Epoch 23/100
# 98/98 [==============================] - 15s 156ms/step - loss: 0.0379 - accuracy: 0.9866 - val_loss: 0.1438 - val_accuracy: 0.9612
# Epoch 24/100
# 98/98 [==============================] - 15s 157ms/step - loss: 0.0286 - accuracy: 0.9915 - val_loss: 0.1618 - val_accuracy: 0.9540
# Epoch 25/100
# 98/98 [==============================] - 15s 157ms/step - loss: 0.0272 - accuracy: 0.9907 - val_loss: 0.1452 - val_accuracy: 0.9572
# Epoch 26/100
# 98/98 [==============================] - 15s 157ms/step - loss: 0.0333 - accuracy: 0.9884 - val_loss: 0.1860 - val_accuracy: 0.9517
# Epoch 27/100
# 98/98 [==============================] - 15s 157ms/step - loss: 0.0686 - accuracy: 0.9766 - val_loss: 0.1282 - val_accuracy: 0.9588
# Epoch 28/100
# 98/98 [==============================] - 15s 156ms/step - loss: 0.0584 - accuracy: 0.9805 - val_loss: 0.1666 - val_accuracy: 0.9493
# Epoch 29/100
# 98/98 [==============================] - 16s 159ms/step - loss: 0.0297 - accuracy: 0.9913 - val_loss: 0.1388 - val_accuracy: 0.9596
# Epoch 30/100
# 98/98 [==============================] - 16s 158ms/step - loss: 0.0218 - accuracy: 0.9923 - val_loss: 0.1706 - val_accuracy: 0.9525
# Epoch 31/100
# 98/98 [==============================] - 16s 167ms/step - loss: 0.0199 - accuracy: 0.9943 - val_loss: 0.1686 - val_accuracy: 0.9580
# Epoch 32/100
# 98/98 [==============================] - 16s 167ms/step - loss: 0.0136 - accuracy: 0.9951 - val_loss: 0.1808 - val_accuracy: 0.9564
# Epoch 33/100
# 98/98 [==============================] - 16s 164ms/step - loss: 0.0077 - accuracy: 0.9977 - val_loss: 0.1882 - val_accuracy: 0.9556
# Epoch 34/100
# 98/98 [==============================] - 16s 167ms/step - loss: 0.0064 - accuracy: 0.9990 - val_loss: 0.2041 - val_accuracy: 0.9540
# Epoch 35/100
# 98/98 [==============================] - 17s 170ms/step - loss: 0.0391 - accuracy: 0.9892 - val_loss: 0.1464 - val_accuracy: 0.9580
# Epoch 36/100
# 98/98 [==============================] - 17s 170ms/step - loss: 0.0361 - accuracy: 0.9861 - val_loss: 0.1567 - val_accuracy: 0.9548
# Epoch 37/100
# 98/98 [==============================] - 17s 170ms/step - loss: 0.0293 - accuracy: 0.9913 - val_loss: 0.1479 - val_accuracy: 0.9548
# Epoch 38/100
# 98/98 [==============================] - 16s 165ms/step - loss: 0.0435 - accuracy: 0.9833 - val_loss: 0.1248 - val_accuracy: 0.9556
# Epoch 39/100
# 98/98 [==============================] - 17s 171ms/step - loss: 0.0275 - accuracy: 0.9920 - val_loss: 0.1688 - val_accuracy: 0.9612
# Epoch 40/100
# 98/98 [==============================] - 17s 169ms/step - loss: 0.0185 - accuracy: 0.9946 - val_loss: 0.1400 - val_accuracy: 0.9604
# Epoch 41/100
# 98/98 [==============================] - 15s 158ms/step - loss: 0.0116 - accuracy: 0.9967 - val_loss: 0.1639 - val_accuracy: 0.9556
# Epoch 42/100
# 98/98 [==============================] - 16s 160ms/step - loss: 0.0101 - accuracy: 0.9972 - val_loss: 0.1565 - val_accuracy: 0.9604
# Epoch 43/100
# 98/98 [==============================] - 16s 159ms/step - loss: 0.0135 - accuracy: 0.9959 - val_loss: 0.1732 - val_accuracy: 0.9548
# Epoch 44/100
# 98/98 [==============================] - 16s 160ms/step - loss: 0.0066 - accuracy: 0.9985 - val_loss: 0.1687 - val_accuracy: 0.9604
# Epoch 45/100
# 98/98 [==============================] - 15s 158ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.1771 - val_accuracy: 0.9580
# Epoch 46/100
# 98/98 [==============================] - 15s 158ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1901 - val_accuracy: 0.9572
# Epoch 47/100
# 98/98 [==============================] - 15s 158ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.2039 - val_accuracy: 0.9572
# Epoch 48/100
# 98/98 [==============================] - 16s 159ms/step - loss: 7.7416e-04 - accuracy: 1.0000 - val_loss: 0.2125 - val_accuracy: 0.9572
# Epoch 49/100
# 98/98 [==============================] - 15s 158ms/step - loss: 6.2625e-04 - accuracy: 1.0000 - val_loss: 0.2194 - val_accuracy: 0.9572
# Epoch 50/100
# 98/98 [==============================] - 15s 157ms/step - loss: 5.3003e-04 - accuracy: 1.0000 - val_loss: 0.2252 - val_accuracy: 0.9572
# Epoch 51/100
# 98/98 [==============================] - 15s 158ms/step - loss: 4.6139e-04 - accuracy: 1.0000 - val_loss: 0.2315 - val_accuracy: 0.9580
# Epoch 52/100
# 98/98 [==============================] - 15s 158ms/step - loss: 4.0169e-04 - accuracy: 1.0000 - val_loss: 0.2353 - val_accuracy: 0.9580
# Epoch 53/100
# 98/98 [==============================] - 15s 157ms/step - loss: 3.5635e-04 - accuracy: 1.0000 - val_loss: 0.2411 - val_accuracy: 0.9580
# Epoch 54/100
# 98/98 [==============================] - 15s 157ms/step - loss: 3.1816e-04 - accuracy: 1.0000 - val_loss: 0.2458 - val_accuracy: 0.9588
# Epoch 55/100
# 98/98 [==============================] - 15s 158ms/step - loss: 2.8543e-04 - accuracy: 1.0000 - val_loss: 0.2501 - val_accuracy: 0.9580
# Epoch 56/100
# 98/98 [==============================] - 15s 157ms/step - loss: 2.5948e-04 - accuracy: 1.0000 - val_loss: 0.2538 - val_accuracy: 0.9588
# Epoch 57/100
# 98/98 [==============================] - 16s 161ms/step - loss: 2.3702e-04 - accuracy: 1.0000 - val_loss: 0.2573 - val_accuracy: 0.9588
# Epoch 58/100
# 98/98 [==============================] - 16s 159ms/step - loss: 2.1779e-04 - accuracy: 1.0000 - val_loss: 0.2607 - val_accuracy: 0.9588
# Epoch 59/100
# 98/98 [==============================] - 16s 159ms/step - loss: 2.0141e-04 - accuracy: 1.0000 - val_loss: 0.2635 - val_accuracy: 0.9588
# Epoch 60/100
# 98/98 [==============================] - 16s 159ms/step - loss: 1.8561e-04 - accuracy: 1.0000 - val_loss: 0.2662 - val_accuracy: 0.9588
# Epoch 61/100
# 98/98 [==============================] - 16s 159ms/step - loss: 1.7339e-04 - accuracy: 1.0000 - val_loss: 0.2690 - val_accuracy: 0.9596
# Epoch 62/100
# 98/98 [==============================] - 15s 158ms/step - loss: 1.6202e-04 - accuracy: 1.0000 - val_loss: 0.2712 - val_accuracy: 0.9596
# Epoch 63/100
# 98/98 [==============================] - 16s 160ms/step - loss: 1.5174e-04 - accuracy: 1.0000 - val_loss: 0.2733 - val_accuracy: 0.9588
# Epoch 64/100
# 98/98 [==============================] - 16s 159ms/step - loss: 1.4317e-04 - accuracy: 1.0000 - val_loss: 0.2757 - val_accuracy: 0.9588
# Epoch 65/100
# 98/98 [==============================] - 16s 159ms/step - loss: 1.3524e-04 - accuracy: 1.0000 - val_loss: 0.2780 - val_accuracy: 0.9588
# Epoch 66/100
# 98/98 [==============================] - 15s 157ms/step - loss: 1.2777e-04 - accuracy: 1.0000 - val_loss: 0.2784 - val_accuracy: 0.9588
# Epoch 67/100
# 98/98 [==============================] - 15s 158ms/step - loss: 1.2063e-04 - accuracy: 1.0000 - val_loss: 0.2810 - val_accuracy: 0.9580
# Epoch 68/100
# 98/98 [==============================] - 16s 159ms/step - loss: 1.1477e-04 - accuracy: 1.0000 - val_loss: 0.2833 - val_accuracy: 0.9580
# Epoch 69/100
# 98/98 [==============================] - 15s 157ms/step - loss: 1.0934e-04 - accuracy: 1.0000 - val_loss: 0.2846 - val_accuracy: 0.9572
# Epoch 70/100
# 98/98 [==============================] - 15s 157ms/step - loss: 1.0454e-04 - accuracy: 1.0000 - val_loss: 0.2865 - val_accuracy: 0.9572
# Epoch 71/100
# 98/98 [==============================] - 15s 158ms/step - loss: 9.9675e-05 - accuracy: 1.0000 - val_loss: 0.2873 - val_accuracy: 0.9572
# Epoch 72/100
# 98/98 [==============================] - 15s 157ms/step - loss: 9.5379e-05 - accuracy: 1.0000 - val_loss: 0.2893 - val_accuracy: 0.9572
# Epoch 73/100
# 98/98 [==============================] - 16s 158ms/step - loss: 9.1330e-05 - accuracy: 1.0000 - val_loss: 0.2901 - val_accuracy: 0.9572
# Epoch 74/100
# 98/98 [==============================] - 15s 157ms/step - loss: 8.7502e-05 - accuracy: 1.0000 - val_loss: 0.2917 - val_accuracy: 0.9572
# Epoch 75/100
# 98/98 [==============================] - 15s 157ms/step - loss: 8.4154e-05 - accuracy: 1.0000 - val_loss: 0.2925 - val_accuracy: 0.9564
# Epoch 76/100
# 98/98 [==============================] - 15s 155ms/step - loss: 8.1054e-05 - accuracy: 1.0000 - val_loss: 0.2935 - val_accuracy: 0.9564
# Epoch 77/100
# 98/98 [==============================] - 15s 158ms/step - loss: 7.8007e-05 - accuracy: 1.0000 - val_loss: 0.2944 - val_accuracy: 0.9564
# Epoch 78/100
# 98/98 [==============================] - 15s 156ms/step - loss: 7.5158e-05 - accuracy: 1.0000 - val_loss: 0.2956 - val_accuracy: 0.9564
# Epoch 79/100
# 98/98 [==============================] - 15s 157ms/step - loss: 7.2542e-05 - accuracy: 1.0000 - val_loss: 0.2965 - val_accuracy: 0.9564
# Epoch 80/100
# 98/98 [==============================] - 15s 156ms/step - loss: 7.0274e-05 - accuracy: 1.0000 - val_loss: 0.2977 - val_accuracy: 0.9564
# Epoch 81/100
# 98/98 [==============================] - 15s 155ms/step - loss: 6.7871e-05 - accuracy: 1.0000 - val_loss: 0.2982 - val_accuracy: 0.9564
# Epoch 82/100
# 98/98 [==============================] - 15s 156ms/step - loss: 6.5625e-05 - accuracy: 1.0000 - val_loss: 0.2992 - val_accuracy: 0.9564
# Epoch 83/100
# 98/98 [==============================] - 15s 157ms/step - loss: 6.3467e-05 - accuracy: 1.0000 - val_loss: 0.3002 - val_accuracy: 0.9564
# Epoch 84/100
# 98/98 [==============================] - 15s 156ms/step - loss: 6.1583e-05 - accuracy: 1.0000 - val_loss: 0.3008 - val_accuracy: 0.9556
# Epoch 85/100
# 98/98 [==============================] - 15s 156ms/step - loss: 5.9753e-05 - accuracy: 1.0000 - val_loss: 0.3011 - val_accuracy: 0.9556
# Epoch 86/100
# 98/98 [==============================] - 15s 155ms/step - loss: 5.8066e-05 - accuracy: 1.0000 - val_loss: 0.3025 - val_accuracy: 0.9556
# Epoch 87/100
# 98/98 [==============================] - 15s 155ms/step - loss: 5.6366e-05 - accuracy: 1.0000 - val_loss: 0.3032 - val_accuracy: 0.9564
# Epoch 88/100
# 98/98 [==============================] - 15s 155ms/step - loss: 5.4822e-05 - accuracy: 1.0000 - val_loss: 0.3039 - val_accuracy: 0.9564
# Epoch 89/100
# 98/98 [==============================] - 15s 154ms/step - loss: 5.3308e-05 - accuracy: 1.0000 - val_loss: 0.3048 - val_accuracy: 0.9572
# Epoch 90/100
# 98/98 [==============================] - 15s 154ms/step - loss: 5.1844e-05 - accuracy: 1.0000 - val_loss: 0.3059 - val_accuracy: 0.9564
# Epoch 91/100
# 98/98 [==============================] - 15s 155ms/step - loss: 5.0545e-05 - accuracy: 1.0000 - val_loss: 0.3069 - val_accuracy: 0.9564
# Epoch 92/100
# 98/98 [==============================] - 15s 156ms/step - loss: 4.9252e-05 - accuracy: 1.0000 - val_loss: 0.3076 - val_accuracy: 0.9572
# Epoch 93/100
# 98/98 [==============================] - 15s 155ms/step - loss: 4.7972e-05 - accuracy: 1.0000 - val_loss: 0.3084 - val_accuracy: 0.9564
# Epoch 94/100
# 98/98 [==============================] - 15s 153ms/step - loss: 4.6833e-05 - accuracy: 1.0000 - val_loss: 0.3094 - val_accuracy: 0.9572
# Epoch 95/100
# 98/98 [==============================] - 15s 155ms/step - loss: 4.5653e-05 - accuracy: 1.0000 - val_loss: 0.3101 - val_accuracy: 0.9572
# Epoch 96/100
# 98/98 [==============================] - 16s 160ms/step - loss: 4.4549e-05 - accuracy: 1.0000 - val_loss: 0.3113 - val_accuracy: 0.9572
# Epoch 97/100
# 98/98 [==============================] - 16s 163ms/step - loss: 4.3535e-05 - accuracy: 1.0000 - val_loss: 0.3123 - val_accuracy: 0.9572
# Epoch 98/100
# 98/98 [==============================] - 15s 154ms/step - loss: 4.2525e-05 - accuracy: 1.0000 - val_loss: 0.3131 - val_accuracy: 0.9572
# Epoch 99/100
# 98/98 [==============================] - 15s 155ms/step - loss: 4.1538e-05 - accuracy: 1.0000 - val_loss: 0.3138 - val_accuracy: 0.9580
# Epoch 100/100
# 98/98 [==============================] - 15s 153ms/step - loss: 4.0612e-05 - accuracy: 1.0000 - val_loss: 0.3148 - val_accuracy: 0.9572
# 40/40 [==============================] - 2s 52ms/step - loss: 0.3148 - accuracy: 0.9572
